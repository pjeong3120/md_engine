# %%
import pickle, os, numpy as np
from src.metrics import compute_traj_energy
from matplotlib import pyplot as plt

# %%
job_dir = './runs/dt_e-1'
with open(os.path.join(job_dir, 'data.pkl'), 'rb') as f:
    data = pickle.load(f)

# %%
energy = compute_traj_energy(data)
print(energy.std())
# Out:
# 3.593699897065565

# %%
plt.plot(np.arange(len(energy)), energy)
